# %% [markdown]
# ### Table of content:
# 1. [Imports](#1.-Imports)
# 2. [Load the dataset](#2.-Load-the-dataset)
# 3. [Basic usage](#3.-Basic-usage)
#     3.1. [Display images list](#3.1-Display-images-list)
#     3.2. [Display class representations](#3.2-Display-class-representations)
#     3.3. [Display images in class tabs layout](#3.3-Display-images-in-class-tabs-layout)
# 4. [Different sequence and data types](#4.-Different-sequence-and-data-types)
#     4.1. [Sequence types](#4.1-Sequence-types)
#     4.2. [Image types](#4.2-Image-types)
# 5. [Order, filter, ignore labels](#5.-Order,-filter,-ignore-labels)
#     5.1. [Ordering](#5.1-Ordering)
#     5.2. [Filtering](#5.2-Filtering)
#     5.3. [Ignoring labels](#5.3-Ignoring-labels)
# 6. [Additional plotting options](#6.-Additional-plotting-options)
#     6.1. [Hiding image URLs](#6.1-Hiding-image-URLs)
# 7. [Force convert images to base64 strings](#7.-Force-convert-images-to-base64-strings)

# %% [markdown]
# # 1. Imports
# [[back to the top](#Table-of-content:)]

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
try:
    sys.path.append('../')
    import ipyplot
except:
    ! {sys.executable} -m pip install ipyplot
    import ipyplot

# %%
import glob
import os
import urllib.request
import zipfile

# %% [markdown]
# # 2. Load the dataset
# [[back to the top](#Table-of-content:)]

# %%
import ipyplot
URLS = (
    [
        "https://i.pinimg.com/originals/77/a6/93/77a6931fd1f6d26a6154b548248b4cd1.jpg",
        "https://i.pinimg.com/originals/d9/bd/8f/d9bd8ffea6c1faf39fc4b57fbd36ba7d.jpg",
        "https://i.pinimg.com/originals/7d/55/a8/7d55a8d5897eea9e0c6115a4c955fe8f.jpg",
        "https://i.pinimg.com/originals/84/86/73/8486730b513f9ce5e249aa810c8d13be.jpg",
        "https://i.pinimg.com/originals/76/bc/d9/76bcd92f191fbb6f5da14b590e2342c4.jpg",
        "https://i.pinimg.com/originals/ff/74/bf/ff74bf933f93578cbf4fa0045e6f2e2b.jpg",
        "https://i.pinimg.com/originals/56/14/43/561443833543bb9a2374cb6564939556.jpg",
        "https://i.pinimg.com/originals/0b/df/68/0bdf686547aff53549c98083650d40b3.jpg",
        "https://i.pinimg.com/originals/56/0a/59/560a596ba0c665dde4f40237d55063f1.jpg",
        "https://i.pinimg.com/originals/86/04/50/860450c6abdeb630999b9f9e0a4d4e26.jpg",
        "https://i.pinimg.com/originals/ac/4c/8b/ac4c8bcec77ccbe842160bf1f57683cf.jpg",
        "https://i.pinimg.com/originals/ed/b5/37/edb53787278f79ebda84770dd6af0758.jpg",
        "https://i.pinimg.com/originals/2b/e7/09/2be709d107bd6b8e98e50ba0aecdfa55.jpg",
        "https://i.pinimg.com/originals/09/55/4c/09554c82e9f42d8a27b9b796c35282f6.png",
        "https://i.pinimg.com/originals/3a/e7/3c/3ae73c7a9ea5c5df8ac70e6b73312450.jpg",
        "https://i.pinimg.com/originals/02/4d/9f/024d9f0e0493c0e5de8769d99b6566bc.jpg",
        "https://i.pinimg.com/originals/c9/6a/74/c96a74a067643068b1558b452774b331.jpg",
    ]
    + [
        "https://i.pinimg.com/originals/f5/cd/55/f5cd55a9b486f7ee60a91b60c7cee0b4.jpg",
        "https://i.pinimg.com/originals/9b/77/ff/9b77ffc57d56072217ae2ae84f233a83.jpg",
        "https://i.pinimg.com/originals/ea/cd/a7/eacda791f11ea67e1a0223aa98d4e3db.jpg",
        "https://i.pinimg.com/originals/35/cd/38/35cd3874368196fa05f8c58f1775b2d8.jpg",
        "https://i.pinimg.com/originals/1f/b1/b7/1fb1b7468da22031ade1aa88eb9be526.jpg",
        "https://i.pinimg.com/originals/43/28/2d/43282db4c5d889d5277d646d0b0a94cb.jpg",
        "https://i.pinimg.com/originals/f9/f0/62/f9f06208137b14f4addf7993ccb073fd.jpg",
        "https://i.pinimg.com/originals/dd/aa/24/ddaa24d9b15623a0468229bf78c847c3.jpg",
        "https://i.pinimg.com/originals/cd/bc/3e/cdbc3ef685d09e76b4d87c871565da67.jpg",
        "https://i.pinimg.com/originals/48/c7/c5/48c7c5f9f22bbbea35047ab9d96fc93f.jpg",
        "https://i.pinimg.com/originals/70/16/f8/7016f8f14f78e52dfe498e6e09be1580.jpg",
        "https://i.pinimg.com/originals/6f/26/f8/6f26f83ff1ff5122fa7af60575cb53e6.jpg",
        "https://i.pinimg.com/originals/7c/59/de/7c59deb3110ee4fd840a039b153f4542.jpg",
        "https://i.pinimg.com/originals/4e/e6/62/4ee662f8644ef1d9e8d0d1ea75f6f4a7.jpg",
        "https://i.pinimg.com/originals/eb/6e/4a/eb6e4a8f9a25c10a23e4a1678a107230.jpg",
        "https://i.pinimg.com/originals/93/80/62/9380621bfde0752dbadb03c77632699b.jpg",
    ]
    + [
        "https://cdn-images.farfetch-contents.com/30/88/87/37/30888737_60382366_480.jpg",
        "https://cdn-images.farfetch-contents.com/30/91/36/57/30913657_60559990_480.jpg",
        "https://cdn-images.farfetch-contents.com/29/78/09/08/29780908_61819855_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/37/68/14/32376814_62340619_480.jpg",
        "https://cdn-images.farfetch-contents.com/28/31/14/83/28311483_57751478_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/09/91/14/32099114_62854331_480.jpg",
        "https://cdn-images.farfetch-contents.com/30/95/98/53/30959853_59865768_480.jpg",
        "https://cdn-images.farfetch-contents.com/29/56/82/45/29568245_61248805_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/52/20/96/32522096_63027500_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/88/72/25/31887225_61618243_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/28/21/37/31282137_62346150_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/76/27/36/31762736_61206137_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/06/58/57/32065857_62067980_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/33/85/10/32338510_62958825_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/05/03/05/32050305_62004629_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/75/39/61/31753961_61304274_480.jpg",
        "https://cdn-images.farfetch-contents.com/22/72/60/63/22726063_52788792_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/38/76/83/32387683_62487234_480.jpg",
        "https://cdn-images.farfetch-contents.com/19/53/56/96/19535696_43554732_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/92/54/84/31925484_62116033_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/20/89/48/32208948_62540603_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/69/21/90/32692190_62960911_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/01/62/56/32016256_61748523_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/19/34/95/32193495_62342788_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/89/24/34/31892434_63040858_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/24/89/25/31248925_60775633_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/74/31/25/31743125_62967963_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/84/82/96/31848296_61542140_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/44/02/71/32440271_62607392_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/33/15/17/32331517_62360995_480.jpg",
        "https://cdn-images.farfetch-contents.com/30/92/34/89/30923489_60200636_480.jpg",
        "https://cdn-images.farfetch-contents.com/30/74/30/67/30743067_59681776_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/03/59/99/32035999_62018018_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/30/99/05/31309905_60779703_480.jpg",
        "https://cdn-images.farfetch-contents.com/14/72/87/58/14728758_23529150_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/56/91/16/31569116_60891257_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/69/21/53/32692153_62960329_480.jpg",
        "https://cdn-images.farfetch-contents.com/30/09/53/29/30095329_60816538_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/05/83/52/32058352_62292988_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/57/43/51/32574351_62782312_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/85/11/48/31851148_61404577_480.jpg",
        "https://cdn-images.farfetch-contents.com/25/09/32/53/25093253_55303152_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/68/28/02/31682802_61423960_480.jpg",
        "https://cdn-images.farfetch-contents.com/32/38/67/39/32386739_62417232_480.jpg",
        "https://cdn-images.farfetch-contents.com/30/58/00/77/30580077_59837570_480.jpg",
        "https://cdn-images.farfetch-contents.com/29/99/41/85/29994185_59194429_480.jpg",
        "https://cdn-images.farfetch-contents.com/17/34/77/59/17347759_36027166_480.jpg",
        "https://cdn-images.farfetch-contents.com/17/71/26/67/17712667_37298899_480.jpg",
        "https://cdn-images.farfetch-contents.com/31/30/99/10/31309910_60788810_480.jpg",
        "https://cdn-images.farfetch-contents.com/25/11/03/51/25110351_55316463_480.jpg",
        "https://cdn-images.farfetch-contents.com/27/08/83/23/27088323_56913390_480.jpg",
        "https://cdn-images.farfetch-contents.com/30/07/99/68/30079968_59245209_480.jpg",
    ]
    + [
        "https://media-assets.grailed.com/prd/listing/temp/d16390dc206644919d1f0785b3dac10a",
        "https://media-assets.grailed.com/prd/listing/temp/69646cd4ae4741baa7957c560c5ad3d7",
        "https://media-assets.grailed.com/prd/listing/temp/1ae00676ded541918cbaf3c85588a312",
        "https://media-assets.grailed.com/prd/listing/temp/fafb1308ecc84b7f8d6bbf5869e6bba0",
        "https://media-assets.grailed.com/prd/listing/temp/bcfcd22b7a984dde8d38431dd5942e91",
        "https://media-assets.grailed.com/prd/listing/temp/6207633a5da6471499a81d4cfb361757",
        "https://media-assets.grailed.com/prd/listing/temp/34a39d4ec06943d5ad9ebe7369097f9d",
        "https://media-assets.grailed.com/prd/listing/temp/1bc32ddc009e47b0a736b823d08a7014",
        "https://media-assets.grailed.com/prd/listing/temp/f5b280b2be58456db31f6e8e0fd626b3",
        "https://media-assets.grailed.com/prd/listing/temp/1cecff84872c4f439924f15ab0fd6b8c",
        "https://media-assets.grailed.com/prd/listing/temp/36c43d12254f49e9bc6f4af76c3f8032",
        "https://media-assets.grailed.com/prd/listing/temp/969b287f0fa7429bb39a4419eb07f564",
        "https://media-assets.grailed.com/prd/listing/temp/ecd7bb45d5544df8aab457fc423ef43d",
        "https://media-assets.grailed.com/prd/listing/temp/6a6af7bda41d4141b25082b7de677f5e",
        "https://media-assets.grailed.com/prd/listing/temp/0324da5854494d4bbd2d34c980930a27",
        "https://media-assets.grailed.com/prd/listing/temp/80939f42e7b3412b916da2b0afe9dfcd",
        "https://media-assets.grailed.com/prd/listing/temp/f826ec70df0b4c26a302ed9491d7e100",
        "https://media-assets.grailed.com/prd/listing/temp/7cca5a32a0bf4ed48880795f0938b813",
        "https://media-assets.grailed.com/prd/listing/temp/c3e0de4bf19d463f901f9aae5bac34f9",
        "https://media-assets.grailed.com/prd/listing/temp/b955eeeae7b1474d9bb5d73f9f9d5d53",
        "https://media-assets.grailed.com/prd/listing/temp/f141195b285b47bbad8e13196b5228a0",
        "https://media-assets.grailed.com/prd/listing/temp/990edd96505a442095b1200031abc5c8",
        "https://media-assets.grailed.com/prd/listing/temp/bada84fbe11f4b3595f4ae6604f2c9fa",
        "https://media-assets.grailed.com/prd/listing/temp/0dcf094f3cc04f8a82aa19df08cd31bf",
        "https://media-assets.grailed.com/prd/listing/temp/e2f4899c3da54a8db5e45d7a54f680e0",
        "https://media-assets.grailed.com/prd/listing/temp/75a1ec13c67846af8824509bf1a6c7f3",
        "https://media-assets.grailed.com/prd/listing/temp/4410ac27a7ae4f77a5b740c58fd1c1e7",
        "https://media-assets.grailed.com/prd/listing/temp/98affbf50bc247f08ae9c260e06cde3e",
        "https://media-assets.grailed.com/prd/listing/temp/879ea367bd9e4c2299b7448eb0d67071",
        "https://media-assets.grailed.com/prd/listing/temp/3cedba28b3074b72b959c1e62577d42d",
        "https://media-assets.grailed.com/prd/listing/temp/e16c97fd908b4c1a9b0dcfb7bd8ec845",
        "https://media-assets.grailed.com/prd/listing/temp/bd483a79256e469faa14c4842e7e9032",
        "https://media-assets.grailed.com/prd/listing/temp/a70d75f537bb40a2a164ffc3bbb0a07f",
        "https://media-assets.grailed.com/prd/listing/temp/525bdb3c516a449596383289bf700dae",
        "https://media-assets.grailed.com/prd/listing/temp/6b38dd5b257d43b181360f174d68d60d",
        "https://media-assets.grailed.com/prd/listing/temp/fe932e4d4a514be586a7976714598c0c",
        "https://media-assets.grailed.com/prd/listing/temp/b44121be439e48b6aecc40833b9f348c",
        "https://media-assets.grailed.com/prd/listing/temp/14403992e614458397b88f861e354206",
        "https://media-assets.grailed.com/prd/listing/temp/14403992e614458397b88f861e354206",
        "https://media-assets.grailed.com/prd/listing/temp/d6645ae816a74851bf994237be9c6a40",
        "https://media-assets.grailed.com/prd/listing/temp/3355d7fcd9a84ba18f732653d8dfdcb3",
        "https://media-assets.grailed.com/prd/listing/temp/ceda5af2ba894272b89ebcd8525917ed",
        "https://media-assets.grailed.com/prd/listing/temp/29d2ea4d29714336b10bf17bf77af041",
        "https://media-assets.grailed.com/prd/listing/temp/2090c1a6bbee43c69d6cadf2b5dbab16",
        "https://media-assets.grailed.com/prd/listing/temp/3090e73dc7d54237824c7de2f036e9f6",
        "https://media-assets.grailed.com/prd/listing/temp/98cf23973c7d48e18299c0f334e45ac6",
        "https://media-assets.grailed.com/prd/listing/temp/64e143e81c85453da005eff964ac34b0",
        "https://media-assets.grailed.com/prd/listing/temp/aa967cd478fe4eff8f27f9dc40377765",
        "https://media-assets.grailed.com/prd/listing/temp/9714291909494b5a873a24ca5fd870e9",
        "https://media-assets.grailed.com/prd/listing/temp/260aa18b800e4f97a8dd12bca9571bf4",
        "https://media-assets.grailed.com/prd/listing/temp/d7fb5eb5c80b478ca9b80de0cf9b2a4a",
        "https://media-assets.grailed.com/prd/listing/temp/f42b116d606044f58456b3da5ebce325",
        "https://media-assets.grailed.com/prd/listing/temp/776f9de6c3e240ccb764f8949c111b12",
        "https://media-assets.grailed.com/prd/listing/temp/7112eccb9e3a4425ab54dc4b9071db94",
        "https://media-assets.grailed.com/prd/listing/temp/f26ef7273491457692ac13e31593eb44",
        "https://media-assets.grailed.com/prd/listing/temp/a436c829712547c2b336797ae4b500b1",
        "https://media-assets.grailed.com/prd/listing/temp/11856c94373b4c068c9b5eea0e2665f1",
        "https://media-assets.grailed.com/prd/listing/temp/74c331ab0d5546b197fe149db2d0a9da",
        "https://media-assets.grailed.com/prd/listing/temp/8524070f2e5b414b99f928dacf9efe4c",
        "https://media-assets.grailed.com/prd/listing/temp/6cec17914fc04c8993500e4fa3729cfc",
        "https://media-assets.grailed.com/prd/listing/temp/1496ab9baaf34a40b86d006c524d8645",
        "https://media-assets.grailed.com/prd/listing/temp/7c264a1d73d14b1b9fe37467cc188383",
        "https://media-assets.grailed.com/prd/listing/temp/401fe75dc3544e00a1a5a1e5fbf92c98",
        "https://media-assets.grailed.com/prd/listing/temp/7d09d4a022a94e81accf6bf4fb14f402",
        "https://media-assets.grailed.com/prd/listing/temp/efc1f5ad61784bc5abdcab454708193d",
        "https://media-assets.grailed.com/prd/listing/temp/b4f6165471cd47a694312cde167743e6",
        "https://media-assets.grailed.com/prd/listing/temp/80da5edee0c64ce18b6484cc736b1ee3",
        "https://media-assets.grailed.com/prd/listing/temp/2ce75fb18b914b0ab791511873f42698",
        "https://media-assets.grailed.com/prd/listing/temp/33b285ba3df540a186f99ab1aa3df6b9",
        "https://media-assets.grailed.com/prd/listing/temp/34d7314960bf4b26821192201cd4b027",
        "https://media-assets.grailed.com/prd/listing/temp/fca9dbc2e77841cdb36e67e4a647a661",
        "https://media-assets.grailed.com/prd/listing/temp/fbf019558d104143be001844adcf9a68",
        "https://media-assets.grailed.com/prd/listing/temp/a3bbf10222ff411481642fa439866109",
        "https://media-assets.grailed.com/prd/listing/temp/de3bf355d0374b41a7bb4dc77f492a0a",
        "https://media-assets.grailed.com/prd/listing/temp/06a0918b89a6467192e79d958f989c2d",
        "https://media-assets.grailed.com/prd/listing/temp/e7dc39f300264bc286a8ba85b4bd43a2",
        "https://media-assets.grailed.com/prd/listing/temp/ad5b564332b34b179042668159e695ce",
        "https://media-assets.grailed.com/prd/listing/temp/d5cf8a16ddf649fa8e5f924c63c423e1",
    ]
)

# %%
ipyplot.plot_images(URLS, img_width=150, max_images=100000)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-U39WESmRLq8WSkiUwM3iDx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-U39WESmRLq8WSkiUwM3iDx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-U39WESmRLq8WSkiUwM3iDx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-U39WESmRLq8WSkiUwM3iDx:checked ~ #ipyplot-html-viewer-textarea-U39WESmRLq8WSkiUwM3iDx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-U39WESmRLq8WSkiUwM3iDx:checked + #ipyplot-html-viewer-label-U39WESmRLq8WSkiUwM3iDx:after {
# ...

# %% [markdown]
# # 3. Basic usage
# [[back to the top](#Table-of-content:)]
# ## 3.1 Display images list
# [[back to the top](#Table-of-content:)]
#
# Displays images based on provided list.
# max_images param limits the number of displayed images (takes top n images only)

# %%
ipyplot.plot_images(images, max_images=10, img_width=150)

# %% [markdown]
# ## 3.2 Display class representations
# [[back to the top](#Table-of-content:)]
#
# Displays first image for each class/label

# %%
ipyplot.plot_class_representations(images, labels, img_width=150)

# %% [markdown]
# ## 3.3 Display images in class tabs layout
# [[back to the top](#Table-of-content:)]
#
# Displays top N images (max_imgs_per_tab) in separate tab for each label/class (based on provided labels list)

# %%
ipyplot.plot_class_tabs(images, labels, max_imgs_per_tab=10, img_width=150)

# %% [markdown]
# #  4. Different sequence and data types
# [[back to the top](#Table-of-content:)]
# ## 4.1 Sequence types
# [[back to the top](#Table-of-content:)]
#
#
# IPyPlot currently support most common sequence types in python including:
# - list
# - numpy.ndarray
# - pandas.Series
#
# In previous examples we were using `images` object to store our images which was of simple python type `list`.
# Now let's try using different sequence types.
#
# ### Using numpy.ndarray as images sequence

# %%
import numpy as np

images_np = np.asarray(images)

ipyplot.plot_images(images_np, max_images=10)

# %% [markdown]
# ### Using pandas.Series as images sequence

# %%
import pandas as pd

images_df = pd.DataFrame()
images_df['images'] = images
images_df['labels'] = labels

ipyplot.plot_images(images_df['images'], max_images=7)

# %% [markdown]
# ## 4.2 Image types
#
# [[back to the top](#Table-of-content:)]
#
# IPyPlot supports passing in images using one of the following types:
# - local image file URL
# - external/remote image file URL
# - PIL.Image objects
# - numpy.ndarray objects
#
# In previous examples we used local image files URLs so now we will focus more on other options.

# %% [markdown]
# ### Displaying images using images as PIL.Image objects

# %%
from PIL import Image

images_pil = [Image.open(image) for image in images]

ipyplot.plot_images(images_pil, max_images=10)

# %% [markdown]
# ### Displaying images using images as numpy.ndarray objects

# %%
import numpy as np

images_np = [np.asarray(image) for image in images_pil]

ipyplot.plot_images(images_np, max_images=10)

# %% [markdown]
# # 5. Order, filter, ignore labels
# [[back to the top](#Table-of-content:)]
#
# By default labels or tabs are sorted alphabetically. Some of the plotting functions allow you to perform custom ordering, filtering or ignoring (not displaying) labels.
#
# ## 5.1 Ordering
# [[back to the top](#Table-of-content:)]
#
# Ordering can be performed:
# - **using `tabs_order` param for `plot_class_tabs` function**

# %%
labels_list_ordered = ["helmets", "boots", "insulated_jackets", "hardshell_jackets", "axes", "tents"]

# %%
ipyplot.plot_class_tabs(
    images, labels, max_imgs_per_tab=5, tabs_order=labels_list_ordered
)

# %% [markdown]
# - **using `labels_order` param for `plot_class_represenations` function**

# %%
ipyplot.plot_class_representations(
    images, labels, labels_order=labels_list_ordered
)

# %% [markdown]
# ## 5.2 Filtering
# [[back to the top](#Table-of-content:)]
#
# Filtering tabs/labels can be achieved the same way as with [ordering](#5.1-Ordering).
# Just create a list of labels/tabs that you want to display and pass it into `tabs_order` or `labels_order` params.

# %%
labels_list_filtered = ["insulated_jackets", "hardshell_jackets"]

# %%
ipyplot.plot_class_tabs(
    images, labels, max_imgs_per_tab=7, tabs_order=labels_list_filtered
)

# %%
ipyplot.plot_class_representations(
    images, labels, labels_order=labels_list_filtered
)

# %% [markdown]
# ## 5.3 Ignoring labels
# [[back to the top](#Table-of-content:)]
#
# If you want to prevent displaying images for specific labels just use `ignore_labels` param as show below

# %%
ignore_list = ["boots", "axes", "helmets", "insulated_jackets", "hardshell_jackets", "tents"]

ipyplot.plot_class_representations(
    images, labels, img_width=150, ignore_labels=ignore_list
)

# %% [markdown]
# # 6. Additional plotting options
# [[back to the top](#Table-of-content:)]
#
# ## 6.1 Hiding image URLs
# [[back to the top](#Table-of-content:)]
#
# By default IPyPlot will display URLs of plotted images.
# If you don't want to show the URL on top of the image, you can set `show_url` to `False`.

# %%
ipyplot.plot_class_representations(
    images, labels, img_width=100, show_url=False
)

# %% [markdown]
# # 7. Force convert images to base64 strings
# [[back to the top](#Table-of-content:)]
#
# Since IPyPlot is using HTML under the hood, by design all the images provided as URL strings are just injected into HTML `img` elements as they are. For all the other image types (numpy.ndarray, PIL.Image) IPyPlot is performing a conversion to base64 strings which are then injected into HTML `img` elements.
# If for any reason you would like to force that behavior for URL strings as well you need to set `force_b64` flag to `True`.
# This param is available for all the plotting functions.

# %%
ipyplot.plot_images(images, max_images=8, force_b64=True)
